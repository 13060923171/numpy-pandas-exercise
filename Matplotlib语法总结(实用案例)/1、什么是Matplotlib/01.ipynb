# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [0,1,2,3,4]  #  x 轴数据
y = [0,1,2,3,4]  #  y 轴数据

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.title('这张图的内容介绍')
plt.xlabel('x 轴数据')
plt.ylabel('y 轴数据')
plt.plot(x,y)
